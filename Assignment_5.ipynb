# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
filterwarnings("ignore")

# %%
df = pd.read_csv("/content/Wholesale customers data - Wholesale customers data.csv")
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
df.shape
# Out:
# (440, 8)

# %%
df.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
df.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# 25%      742.250000        256.750000    408.250000
# 50%     1526.000000        816.500000    965.500000
# 75%     3554.250000       3922.000000   1820.250000
# max    60869.000000      40827.000000  47943.000000

# %%
df.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicassen'],
#       dtype='object')

# %%
# All features are numerical feature i.e. there is no any categorical feature in our dataset

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
df = pd.DataFrame(scaled_data,columns = df.columns)
df.head()
# Out:
#    Channel  Region     Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# 0      1.0     1.0  0.112940  0.130727  0.081464  0.003106          0.065427
# 1      1.0     1.0  0.062899  0.132824  0.103097  0.028548          0.080590
# 2      1.0     1.0  0.056622  0.119181  0.082790  0.039116          0.086052
# 3      0.0     1.0  0.118254  0.015536  0.045464  0.104842          0.012346
# 4      1.0     1.0  0.201626  0.072914  0.077552  0.063934          0.043455
#
#    Delicassen
# 0    0.027847
# 1    0.036984
# 2    0.163559
# 3    0.037234
# 4    0.108093

# %%
x = df.drop("Channel",axis = 1)
y = df.Channel

# %%
df
# Out:
#      Channel  Region     Fresh      Milk   Grocery    Frozen  \
# 0        1.0     1.0  0.112940  0.130727  0.081464  0.003106
# 1        1.0     1.0  0.062899  0.132824  0.103097  0.028548
# 418          0.165025    0.016124
# 419          0.038629    0.031665
# 420          0.166936    0.028995
# 421          0.083578    0.037151
# 422          0.023148    0.025344
# 423          0.044092    0.013872
# 424          0.078630    0.005131
# 425          0.002572    0.039278
# 426          0.124339    0.039445
# 427          0.010680    0.024197
# 428          0.020748    0.006550
# 429          0.001984    0.052107
# 430          0.005830    0.043325
# 431          0.033657    0.031185
# 432          0.032456    0.008177
# 433          0.008647    0.030163
# 434          0.058005    0.017418
# 435          0.004385    0.045912
# 436          0.002205    0.048874
# 437          0.363463    0.038882
# 438          0.004042    0.044264
# 439          0.011611    0.001022

# %%
# Analysing the distribution of data.
plt.figure(figsize=(25,30),facecolor='white')
plotnumber = 1
sns.set()
for column in df:
    if plotnumber <= 9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=30)
    plotnumber += 1

plt.show()

# %%
df.Channel.value_counts()
# Out:
# 0.0    298
# 1.0    142
# Name: Channel, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
x_resampled, y_resampled = SMOTE().fit_resample(x, y)

# %%
x_resampled.shape, y_resampled.shape
# Out:
# ((596, 7), (596,))

# %%
y_resampled.value_counts()
# Out:
# 1.0    298
# 0.0    298
# Name: Channel, dtype: int64

# %%
df = pd.concat([x_resampled,y_resampled],axis = 1)

# %%
# Analysing the distribution of data.
plt.figure(figsize=(25,30),facecolor='white')
plotnumber = 1
sns.set()
for column in df:
    if plotnumber <= 9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=30)
    plotnumber += 1
plt.show()

# %% [markdown]
# ### There is also chance of outliers in our dataset, so to check outlier I'm using the boxplot method

# %%
plt.boxplot(df)
plt.show()

# %%
for feature in df.columns:
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_fence = Q1-1.5*IQR
    upper_fence = Q3+1.5*IQR
    for i in range(len(df)):
        outlier = df[feature][i]
        if outlier > upper_fence:
            df[feature][i] = upper_fence
        elif outlier < lower_fence:
            df[feature][i] = lower_fence

# %%
plt.boxplot(df)
plt.show()

# %%
corr = df.corr()
z = corr.style.highlight_between(left=-1,right=-0.90,color='red').highlight_between(left=0.90,right=1,color='red')
z
# Out:
# <style type="text/css">
# #T_54baa_row0_col0, #T_54baa_row1_col1, #T_54baa_row2_col2, #T_54baa_row3_col3, #T_54baa_row4_col4, #T_54baa_row5_col5, #T_54baa_row6_col6, #T_54baa_row7_col7 {
#   background-color: red;
# }
# </style>
# <table id="T_54baa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54baa_level0_col0" class="col_heading level0 col0" >Region</th>
#       <th id="T_54baa_level0_col1" class="col_heading level0 col1" >Fresh</th>
#       <th id="T_54baa_level0_col2" class="col_heading level0 col2" >Milk</th>
#       <th id="T_54baa_level0_col3" class="col_heading level0 col3" >Grocery</th>
#       <th id="T_54baa_level0_col4" class="col_heading level0 col4" >Frozen</th>
#       <th id="T_54baa_level0_col5" class="col_heading level0 col5" >Detergents_Paper</th>
#       <th id="T_54baa_level0_col6" class="col_heading level0 col6" >Delicassen</th>
#       <th id="T_54baa_level0_col7" class="col_heading level0 col7" >Channel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54baa_level0_row0" class="row_heading level0 row0" >Region</th>
#       <td id="T_54baa_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_54baa_row0_col1" class="data row0 col1" >0.069802</td>
#       <td id="T_54baa_row0_col2" class="data row0 col2" >-0.008469</td>
#       <td id="T_54baa_row0_col3" class="data row0 col3" >-0.024098</td>
#       <td id="T_54baa_row0_col4" class="data row0 col4" >-0.090045</td>
#       <td id="T_54baa_row0_col5" class="data row0 col5" >-0.033612</td>
#       <td id="T_54baa_row0_col6" class="data row0 col6" >0.019084</td>
#       <td id="T_54baa_row0_col7" class="data row0 col7" >0.063316</td>
#     </tr>
#     <tr>
#       <th id="T_54baa_level0_row1" class="row_heading level0 row1" >Fresh</th>
#       <td id="T_54baa_row1_col0" class="data row1 col0" >0.069802</td>
#       <td id="T_54baa_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_54baa_row1_col2" class="data row1 col2" >-0.079209</td>
#       <td id="T_54baa_row1_col3" class="data row1 col3" >-0.153057</td>
#       <td id="T_54baa_row1_col4" class="data row1 col4" >0.355800</td>
#       <td id="T_54baa_row1_col5" class="data row1 col5" >-0.244899</td>
#       <td id="T_54baa_row1_col6" class="data row1 col6" >0.249897</td>
#       <td id="T_54baa_row1_col7" class="data row1 col7" >-0.206038</td>
#     </tr>
#     <tr>
#       <th id="T_54baa_level0_row2" class="row_heading level0 row2" >Milk</th>
#       <td id="T_54baa_row2_col0" class="data row2 col0" >-0.008469</td>
#       <td id="T_54baa_row2_col1" class="data row2 col1" >-0.079209</td>
#       <td id="T_54baa_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_54baa_row2_col3" class="data row2 col3" >0.794909</td>
#       <td id="T_54baa_row2_col4" class="data row2 col4" >-0.082232</td>
#       <td id="T_54baa_row2_col5" class="data row2 col5" >0.710174</td>
#       <td id="T_54baa_row2_col6" class="data row2 col6" >0.336596</td>
#       <td id="T_54baa_row2_col7" class="data row2 col7" >0.573767</td>
#     </tr>
#     <tr>
#       <th id="T_54baa_level0_row3" class="row_heading level0 row3" >Grocery</th>
#       <td id="T_54baa_row3_col0" class="data row3 col0" >-0.024098</td>
#       <td id="T_54baa_row3_col1" class="data row3 col1" >-0.153057</td>
#       <td id="T_54baa_row3_col2" class="data row3 col2" >0.794909</td>
#       <td id="T_54baa_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_54baa_row3_col4" class="data row3 col4" >-0.188489</td>
#       <td id="T_54baa_row3_col5" class="data row3 col5" >0.893765</td>
#       <td id="T_54baa_row3_col6" class="data row3 col6" >0.252095</td>
#       <td id="T_54baa_row3_col7" class="data row3 col7" >0.680104</td>
#     </tr>
#     <tr>
#       <th id="T_54baa_level0_row4" class="row_heading level0 row4" >Frozen</th>
#       <td id="T_54baa_row4_col0" class="data row4 col0" >-0.090045</td>
#       <td id="T_54baa_row4_col1" class="data row4 col1" >0.355800</td>
#       <td id="T_54baa_row4_col2" class="data row4 col2" >-0.082232</td>
#       <td id="T_54baa_row4_col3" class="data row4 col3" >-0.188489</td>
#       <td id="T_54baa_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_54baa_row4_col5" class="data row4 col5" >-0.256126</td>
#       <td id="T_54baa_row4_col6" class="data row4 col6" >0.215030</td>
#       <td id="T_54baa_row4_col7" class="data row4 col7" >-0.323872</td>
#     </tr>
#     <tr>
#       <th id="T_54baa_level0_row5" class="row_heading level0 row5" >Detergents_Paper</th>
#       <td id="T_54baa_row5_col0" class="data row5 col0" >-0.033612</td>
#       <td id="T_54baa_row5_col1" class="data row5 col1" >-0.244899</td>
#       <td id="T_54baa_row5_col2" class="data row5 col2" >0.710174</td>
#       <td id="T_54baa_row5_col3" class="data row5 col3" >0.893765</td>
#       <td id="T_54baa_row5_col4" class="data row5 col4" >-0.256126</td>
#       <td id="T_54baa_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_54baa_row5_col6" class="data row5 col6" >0.158105</td>
#       <td id="T_54baa_row5_col7" class="data row5 col7" >0.722426</td>
#     </tr>
#     <tr>
#       <th id="T_54baa_level0_row6" class="row_heading level0 row6" >Delicassen</th>
#       <td id="T_54baa_row6_col0" class="data row6 col0" >0.019084</td>
#       <td id="T_54baa_row6_col1" class="data row6 col1" >0.249897</td>
#       <td id="T_54baa_row6_col2" class="data row6 col2" >0.336596</td>
#       <td id="T_54baa_row6_col3" class="data row6 col3" >0.252095</td>
#       <td id="T_54baa_row6_col4" class="data row6 col4" >0.215030</td>
#       <td id="T_54baa_row6_col5" class="data row6 col5" >0.158105</td>
#       <td id="T_54baa_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_54baa_row6_col7" class="data row6 col7" >0.175548</td>
#     </tr>
#     <tr>
#       <th id="T_54baa_level0_row7" class="row_heading level0 row7" >Channel</th>
#       <td id="T_54baa_row7_col0" class="data row7 col0" >0.063316</td>
#       <td id="T_54baa_row7_col1" class="data row7 col1" >-0.206038</td>
#       <td id="T_54baa_row7_col2" class="data row7 col2" >0.573767</td>
#       <td id="T_54baa_row7_col3" class="data row7 col3" >0.680104</td>
#       <td id="T_54baa_row7_col4" class="data row7 col4" >-0.323872</td>
#       <td id="T_54baa_row7_col5" class="data row7 col5" >0.722426</td>
#       <td id="T_54baa_row7_col6" class="data row7 col6" >0.175548</td>
#       <td id="T_54baa_row7_col7" class="data row7 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(10,4))
sns.heatmap(corr,annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # checking 'P>|t|' > 0.05 and vif > 5

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
x = sm.add_constant(x)

# %%
lr = sm.Logit(y,x).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.228740
#          Iterations 9

# %%
def df_of_vif_pvalue():
    p_value_df = pd.DataFrame(lr.pvalues.apply(lambda x: round(x,6))).reset_index()
    p_value_df.columns=["feature_names",'p_values']
    def VIF(x):
        vif_df = pd.DataFrame()
        vif_df["feature_names"] = x.columns
        vif_df["vif"] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
        vif_df["vif"] = round(vif_df["vif"],2)
        vif_df = vif_df.sort_values(by = "vif",ascending = False)
        return vif_df
    global vif_pvalue_df
    vif_pvalue_df = pd.merge(p_value_df,VIF(x), on = "feature_names")
    return vif_pvalue_df

# %%
def High_vif_pvalue(vif_pvalue_df):
    global lst_feature_to_del
    lst_feature_to_del = []
    '''vif_pvalue is a DataFrame having pvalues and vif'''
    for i in range(len(vif_pvalue_df)):
        if vif_pvalue_df["vif"][i] > 5 and vif_pvalue_df["p_values"][i] >0.05:
            lst_feature_to_del.append(vif_pvalue_df["feature_names"][i])
    return lst_feature_to_del

# %%
df_of_vif_pvalue()
vif_pvalue_df
# Out:
#       feature_names  p_values   vif
# 0             const  0.000000  6.60
# 1            Region  0.117160  1.01
# 2             Fresh  0.804192  1.19
# 3              Milk  0.162535  2.55
# 4           Grocery  0.062630  8.79
# 5            Frozen  0.090734  1.32
# 6  Detergents_Paper  0.000000  8.10
# 7        Delicassen  0.469344  1.52

# %%
High_vif_pvalue(vif_pvalue_df)
lst_feature_to_del
# Out:
# ['Grocery']

# %%
x.drop("Grocery",inplace = True,axis = 1)

# %%
df_of_vif_pvalue()
# Out:
#       feature_names  p_values   vif
# 0             const  0.000000  6.42
# 1            Region  0.117160  1.01
# 2             Fresh  0.804192  1.18
# 3              Milk  0.162535  2.37
# 4            Frozen  0.090734  1.32
# 5  Detergents_Paper  0.000000  2.06
# 6        Delicassen  0.469344  1.47

# %%
#There is no feature having vif value greater than 5.So now check p_value only.

# %%
def check_pvalue(vif_pvalue_df,P_value_column):
    High_vif_features = {}
    for i,value in enumerate(P_value_column):
        if value > 0.05:
            High_vif_features[vif_pvalue_df.loc[i][0]] = value
    return High_vif_features

# %%
check_pvalue(vif_pvalue_df,vif_pvalue_df["p_values"])
# Out:
# {'Region': 0.11716,
#  'Fresh': 0.804192,
#  'Milk': 0.162535,
#  'Frozen': 0.090734,
#  'Delicassen': 0.469344}

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=36)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((352, 7), (352,), (88, 7), (88,))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier,BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# %%
model_params = {
    'svc': {'model': SVC(gamma ="auto"),
            'params' : {
                "C" :[1, 10,100,201],
                'kernel': [ 'rbf','linear']}
           },
    "random_forest": {'model' : RandomForestClassifier(),
                      'params' : {'n_estimators' : [200,250,100,150,300]}
                     },
    'logistic_regression' : {
        'model' : LogisticRegression(solver = "liblinear"),
        'params':{"C" : [1,5,10,50]}
    },
    "GradientBoostingClassifier":{"model": GradientBoostingClassifier(),
                                "params" : {'learning_rate':[0.1,0.2,0.3,0.4],'n_estimators':list(range(1,300,50)),'subsample':[1.0,2.0,3.0,4.0],'criterion':['friedman_mse']}
                                  },
    "KNN" : {"model" : KNeighborsClassifier(),
            "params" : {"n_neighbors":list(range(3,35,6)),'weights':['uniform'],'algorithm':['auto'],'leaf_size':list(range(10,100,15)),'p':[2,4,5,6],'metric':['minkowski']}
            }
    }

# %%
scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp["model"],mp['params'], cv =10, return_train_score = False)
    clf.fit(x, y)
    scores.append({
        "model" : model_name,
        'best_score': clf.best_score_,
        'best_params' : clf.best_params_})
mod_df = pd.DataFrame(scores,columns = ["model","best_score","best_params"])
mod_df
# Out:
#                         model  best_score  \
# 0                         svc    0.906818
# 1               random_forest    0.920455
# 2         logistic_regression    0.902273
# 3  GradientBoostingClassifier    0.918182
# 4                         KNN    0.879545
#
#                                          best_params
# 0                     {'C': 100, 'kernel': 'linear'}
# 1                              {'n_estimators': 200}
# 2                                          {'C': 50}
# 3  {'criterion': 'friedman_mse', 'learning_rate':...
# 4  {'algorithm': 'auto', 'leaf_size': 10, 'metric...

# %%
model_params = {
    'decision_tree': {'model': DecisionTreeClassifier(),
            'params' : {
                "criterion" :["gini", "entropy", "log_loss"],
                'splitter': [ 'best'],
                "min_samples_split": [2,4,6],
                'random_state': [36]}
           },
    "AdaBoostDT": {'model' : AdaBoostClassifier(),
                   'params' : {'n_estimators' : [10,50,100,150,200],
                               'learning_rate':[0.1,0.2,0.3,0.4],
                               "algorithm" : ['SAMME', 'SAMME.R']}
                     },
    "AdaBoostRandomForest": {'model' : AdaBoostClassifier(),
                   'params' : {"base_estimator":[RandomForestClassifier()],
                               'n_estimators' : [400,250,300,450,200],
                               'learning_rate':[0.1,0.2,0.3,0.4],
                               "algorithm" : ['SAMME', 'SAMME.R']}
                     },
    'xgboost_classifier' : {'model' : XGBClassifier(),
        'params':{"n_estimators" : [1,30,100,150,200],
                 'learning_rate':[0.1,0.2,0.3,0.4],
                 }
                           }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp["model"],mp['params'], cv =10, return_train_score = False)
    clf.fit(x, y)
    scores.append({
        "model" : model_name,
        'best_score': clf.best_score_,
        'best_params' : clf.best_params_})
mod_df1 = pd.DataFrame(scores,columns = ["model","best_score","best_params"])
mod_df1
# Out:
#                   model  best_score  \
# 0         decision_tree    0.865909
# 1            AdaBoostDT    0.922727
# 2  AdaBoostRandomForest    0.925000
# 3    xgboost_classifier    0.925000
#
#                                          best_params
# 0  {'criterion': 'gini', 'min_samples_split': 6, ...
# 1  {'algorithm': 'SAMME', 'learning_rate': 0.4, '...
# 2  {'algorithm': 'SAMME', 'base_estimator': Rando...
# 3        {'learning_rate': 0.4, 'n_estimators': 100}

# %%
modeles_df = pd.concat([mod_df,mod_df1]).set_index('model',drop = True)
modeles_df
# Out:
#                             best_score  \
# model
# svc                           0.906818
# random_forest                 0.920455
# logistic_regression           0.902273
# GradientBoostingClassifier    0.918182
# KNN                           0.879545
# decision_tree                 0.865909
# AdaBoostDT                    0.922727
# AdaBoostRandomForest          0.925000
# xgboost_classifier            0.925000
#
#                                                                   best_params
# model
# svc                                            {'C': 100, 'kernel': 'linear'}
# random_forest                                           {'n_estimators': 200}
# logistic_regression                                                 {'C': 50}
# GradientBoostingClassifier  {'criterion': 'friedman_mse', 'learning_rate':...
# KNN                         {'algorithm': 'auto', 'leaf_size': 10, 'metric...
# decision_tree               {'criterion': 'gini', 'min_samples_split': 6, ...
# AdaBoostDT                  {'algorithm': 'SAMME', 'learning_rate': 0.4, '...
# AdaBoostRandomForest        {'algorithm': 'SAMME', 'base_estimator': Rando...
# xgboost_classifier                {'learning_rate': 0.4, 'n_estimators': 100}

# %%
best_parameter_for_AdaBoostRandomForest = modeles_df.loc["AdaBoostRandomForest"]['best_params']
best_parameter_for_AdaBoostRandomForest
# Out:
# {'algorithm': 'SAMME',
#  'base_estimator': RandomForestClassifier(),
#  'learning_rate': 0.2,
#  'n_estimators': 250}

# %%
model = AdaBoostClassifier(algorithm = 'SAMME',
                           base_estimator = RandomForestClassifier(),
                           learning_rate = 0.2,
                           n_estimators = 200 )
model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME', base_estimator=RandomForestClassifier(),
#                    learning_rate=0.2, n_estimators=200)

# %%
y_test_pred = model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve

# %%
cm = confusion_matrix(y_test,y_test_pred)
cm
# Out:
# array([[55,  3],
#        [ 2, 28]])

# %%
TN=cm[0,0]
TP=cm[1,1]
FN=cm[1,0]
FP=cm[0,1]
sensitivity=TP/float(TP+FN)
specificity=TN/float(TN+FP)

# %%
print('The acuuracy of the model = TP+TN/(TP+TN+FP+FN) = ',(TP+TN)/float(TP+TN+FP+FN),'\n\n',

'Missclassifications = 1-Accuracy = ',1-((TP+TN)/float(TP+TN+FP+FN)),'\n\n',

'Sensitivity/Recall or True Positive Rate = TP/(TP+FN) = ',TP/float(TP+FN),'\n\n',

'Specificity or True Negative Rate = TN/(TN+FP) = ',TN/float(TN+FP),'\n\n',

'Precision/Positive Predictive value = TP/(TP+FP) = ',TP/float(TP+FP),'\n\n',

'Negative predictive Value = TN/(TN+FN) = ',TN/float(TN+FN),'\n\n',

'Positive Likelihood Ratio = Sensitivity/(1-Specificity) = ',sensitivity/(1-specificity),'\n\n',

'Negative likelihood Ratio = (1-Sensitivity)/Specificity = ',(1-sensitivity)/specificity)
# Out:
# The acuuracy of the model = TP+TN/(TP+TN+FP+FN) =  0.9431818181818182
#
#  Missclassifications = 1-Accuracy =  0.05681818181818177
#
#  Sensitivity/Recall or True Positive Rate = TP/(TP+FN) =  0.9333333333333333
#
#  Specificity or True Negative Rate = TN/(TN+FP) =  0.9482758620689655
#
#  Precision/Positive Predictive value = TP/(TP+FP) =  0.9032258064516129
#
#  Negative predictive Value = TN/(TN+FN) =  0.9649122807017544
#
#  Positive Likelihood Ratio = Sensitivity/(1-Specificity) =  18.044444444444448
#
#  Negative likelihood Ratio = (1-Sensitivity)/Specificity =  0.07030303030303028

# %%
print("accuracy of best model(AdaBoostClassifier) : ",accuracy_score(y_test,y_test_pred)*100,"percent")
# Out:
# accuracy of best model(AdaBoostClassifier) :  94.31818181818183 percent

# %%
y_pred_prob = model.predict_proba(x_test)
y_pred_prob = y_pred_prob[:,1]

# %%
roc_auc_score_test = roc_auc_score(y_test,y_pred_prob)
roc_auc_score_test
# Out:
# 0.9408045977011494

# %%
fpr,tpr,thresholds = roc_curve(y_test,y_pred_prob)

# %%
plt.plot(fpr,tpr,color= "orange",label = "ROC")
plt.plot([0,1],[0,1],color='blue',linestyle='--',label='ROC Curve test using svc(area = %0.4f)' % roc_auc_score_test)
plt.xlabel('False possitive rate')
plt.ylabel('True possitive rate')
plt.title('roc curve test using svc')
plt.legend()
plt.show()
